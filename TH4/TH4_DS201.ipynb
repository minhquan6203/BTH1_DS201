# %%
# !pip install yacs
# !pip install SentencePiece
# !pip install transformers datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.3 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/minhquan6203/DS201
# Out:
# Cloning into 'DS201'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 146 (delta 4), reused 21 (delta 3), pack-reused 122
# Receiving objects: 100% (146/146), 42.44 MiB | 15.16 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# Updating files: 100% (46/46), done.

# %% [markdown]
# # prepare data

# %%
# !gdown '138wGNPNSweuM8f5JyF-askthG4M33Dap'
# !gdown '138dsVRyxbnz04cME05ja2F1JeRZLwUFJ'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=138wGNPNSweuM8f5JyF-askthG4M33Dap
# To: /content/MNIST.zip
# 100% 61.5M/61.5M [00:00<00:00, 159MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=138dsVRyxbnz04cME05ja2F1JeRZLwUFJ
# To: /content/CIFAR.zip
# 100% 147M/147M [00:02<00:00, 72.6MB/s]

# %%
# !unzip /content/CIFAR.zip
# !unzip /content/MNIST.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: mnist_png/mnist_png/training/6/43498.png
#   inflating: mnist_png/mnist_png/training/6/43505.png
#   inflating: mnist_png/mnist_png/training/6/43518.png
#   inflating: mnist_png/mnist_png/training/6/43545.png
#   inflating: mnist_png/mnist_png/training/6/43564.png
#   inflating: mnist_png/mnist_png/training/6/43569.png
#   inflating: mnist_png/mnist_png/training/6/43572.png
#   inflating: mnist_png/mnist_png/training/6/43581.png
#   inflating: mnist_png/mnist_png/training/6/43582.png
#   inflating: mnist_png/mnist_png/training/6/43586.png
#   inflating: mnist_png/mnist_png/training/6/43589.png
#   inflating: mnist_png/mnist_png/training/6/43592.png
#   inflating: mnist_png/mnist_png/training/6/43594.png
#   inflating: mnist_png/mnist_png/training/6/4360.png
#   inflating: mnist_png/mnist_png/training/6/43605.png
#   inflating: mnist_png/mnist_png/training/6/43620.png
# ...

# %% [markdown]
# # training & evaluate

# %%
# !rm -rf /content/save

# %%
# !python /content/DS201/TH3/main.py --config /content/DS201/TH3/config/config.yaml
